# %%
import requests
from bs4 import BeautifulSoup

# %%
url = "https://services.rec.rutgers.edu/Program/GetProgramDetails?courseId=0c0f9f29-eabf-4316-93a1-d0693b61e08f&semesterId=3302ba85-8b33-4145-b755-2d709e0ec9ef"

# %%
res = requests.get(url)
soup = BeautifulSoup(res.text, 'html.parser')

# %%
# find all the card instances
cards = soup.find_all(class_='program-schedule-card-caption')
cards
# Out:
# [<div class="caption program-schedule-card-caption" data-instance-dates="Thursday, June 24, 2021" data-instance-id="2ccd99a7-9637-4b3e-bb82-824eb5715df9" data-instance-times="11:00 AM - 12:30 PM">
#  <label class="program-schedule-card-header">
#  					Thursday, June 24, 2021
#  			</label>
#  <div>
#  <small>
#  					11:00 AM - 12:30 PM
#  					<span class="pull-right">
#  <small>3 spot(s) available</small>
#  </span>
#  </small>
#  </div>
#  <br>
#  <a aria-label="Login to register for Thursday, June 24, 2021" class="btn btn-primary" href="#" onclick="showLogin('/Program/GetProgramDetails?courseId=0c0f9f29-eabf-4316-93a1-d0693b61e08f&amp;semesterId=3302ba85-8b33-4145-b755-2d709e0ec9ef')">Register</a>
#  </br></div>,
#  <div class="caption program-schedule-card-caption" data-instance-dates="Thursday, June 24, 2021" data-instance-id="4b48b8e4-d0ca-4d4b-a536-2ee0aaa07329" data-instance-times="12:30 PM - 2:00 PM">
#  <label class="program-schedule-card-header">
#  					Thursday, June 24, 2021
#  			</label>
#  <div>
#  <small>
#  					12:30 PM - 2:00 PM
#  					<span class="pull-right">
#  <small>1 spot(s) available</small>
#  </span>
#  </small>
#  </div>
#  <br>
#  <a aria-label="Login to register for Thursday, June 24, 2021" class="btn btn-primary" href="#" onclick="showLogin('/Program/GetProgramDetails?courseId=0c0f9f29-eabf-4316-93a1-d0693b61e08f&amp;semesterId=3302ba85-8b33-4145-b755-2d709e0ec9ef')">Register</a>
#  </br></div>,
#  <div class="caption program-schedule-card-caption" data-instance-dates="Thursday, June 24, 2021" data-instance-id="5afd779f-d2de-435d-9490-a7051dcac8e4" data-instance-times="4:00 PM - 5:30 PM">
#  <label class="program-schedule-card-header">
#  					Thursday, June 24, 2021
#  			</label>
#  <div>
#  <small>
#  					4:00 PM - 5:30 PM
#  					<span class="pull-right">
#  <small>No Spots Available</small>
#  </span>
#  </small>
#  </div>
#  <br>
#  <a aria-label="Login to register for Thursday, June 24, 2021" class="btn btn-primary" href="#" onclick="showLogin('/Program/GetProgramDetails?courseId=0c0f9f29-eabf-4316-93a1-d0693b61e08f&amp;semesterId=3302ba85-8b33-4145-b755-2d709e0ec9ef')">Register</a>
#  </br></div>,
#  <div class="caption program-schedule-card-caption" data-instance-dates="Thursday, June 24, 2021" data-instance-id="c86ba9ba-ae6b-49e3-b663-f990d97cc8b5" data-instance-times="5:30 PM - 7:00 PM">
#  <label class="program-schedule-card-header">
#  					Thursday, June 24, 2021
#  			</label>
#  <div>
#  <small>
#  					5:30 PM - 7:00 PM
#  					<span class="pull-right">
#  <small>No Spots Available</small>
#  </span>
#  </small>
#  </div>
#  <br>
#  <a aria-label="Login to register for Thursday, June 24, 2021" class="btn btn-primary" href="#" onclick="showLogin('/Program/GetProgramDetails?courseId=0c0f9f29-eabf-4316-93a1-d0693b61e08f&amp;semesterId=3302ba85-8b33-4145-b755-2d709e0ec9ef')">Register</a>
#  </br></div>,
#  <div class="caption program-schedule-card-caption" data-instance-dates="Friday, June 25, 2021" data-instance-id="230c2142-7626-40a8-aab7-76556fb941ae" data-instance-times="11:00 AM - 12:30 PM">
#  <label class="program-schedule-card-header">
#  					Friday, June 25, 2021
#  			</label>
#  <div>
#  <small>
#  					11:00 AM - 12:30 PM
#  					<span class="pull-right">
#  <small>No Spots Available</small>
#  </span>
#  </small>
#  </div>
#  <br>
#  <a aria-label="Login to register for Friday, June 25, 2021" class="btn btn-primary" href="#" onclick="showLogin('/Program/GetProgramDetails?courseId=0c0f9f29-eabf-4316-93a1-d0693b61e08f&amp;semesterId=3302ba85-8b33-4145-b755-2d709e0ec9ef')">Register</a>
#  </br></div>,
#  <div class="caption program-schedule-card-caption" data-instance-dates="Friday, June 25, 2021" data-instance-id="68df245e-61bd-418a-ae9b-3f3d7820c10d" data-instance-times="12:30 PM - 2:00 PM">
#  <label class="program-schedule-card-header">
#  					Friday, June 25, 2021
#  			</label>
#  <div>
#  <small>
#  					12:30 PM - 2:00 PM
#  					<span class="pull-right">
#  <small>No Spots Available</small>
#  </span>
#  </small>
#  </div>
#  <br>
#  <a aria-label="Login to register for Friday, June 25, 2021" class="btn btn-primary" href="#" onclick="showLogin('/Program/GetProgramDetails?courseId=0c0f9f29-eabf-4316-93a1-d0693b61e08f&amp;semesterId=3302ba85-8b33-4145-b755-2d709e0ec9ef')">Register</a>
#  </br></div>,
#  <div class="caption program-schedule-card-caption" data-instance-dates="Friday, June 25, 2021" data-instance-id="49c0514b-cd41-40ab-a1f5-0eef58a1c2c1" data-instance-times="4:00 PM - 5:30 PM">
#  <label class="program-schedule-card-header">
#  					Friday, June 25, 2021
#  			</label>
#  <div>
#  <small>
#  					4:00 PM - 5:30 PM
#  					<span class="pull-right">
#  <small>No Spots Available</small>
#  </span>
#  </small>
#  </div>
#  <br>
#  <a aria-label="Login to register for Friday, June 25, 2021" class="btn btn-primary" href="#" onclick="showLogin('/Program/GetProgramDetails?courseId=0c0f9f29-eabf-4316-93a1-d0693b61e08f&amp;semesterId=3302ba85-8b33-4145-b755-2d709e0ec9ef')">Register</a>
#  </br></div>,
#  <div class="caption program-schedule-card-caption" data-instance-dates="Friday, June 25, 2021" data-instance-id="288a306e-5c6b-4692-af16-9d421fc24451" data-instance-times="5:30 PM - 7:00 PM">
#  <label class="program-schedule-card-header">
#  					Friday, June 25, 2021
#  			</label>
#  <div>
#  <small>
#  					5:30 PM - 7:00 PM
#  					<span class="pull-right">
#  <small>No Spots Available</small>
#  </span>
#  </small>
#  </div>
#  <br>
#  <a aria-label="Login to register for Friday, June 25, 2021" class="btn btn-primary" href="#" onclick="showLogin('/Program/GetProgramDetails?courseId=0c0f9f29-eabf-4316-93a1-d0693b61e08f&amp;semesterId=3302ba85-8b33-4145-b755-2d709e0ec9ef')">Register</a>
#  </br></div>,
#  <div class="caption program-schedule-card-caption" data-instance-dates="Saturday, June 26, 2021" data-instance-id="7afeb5f6-8083-40ef-9377-5f82d3ca13f1" data-instance-times="11:00 AM - 12:30 PM">
#  <label class="program-schedule-card-header">
#  					Saturday, June 26, 2021
#  			</label>
#  <div>
#  <small>
#  					11:00 AM - 12:30 PM
#  					<span class="pull-right">
#  <small>No Spots Available</small>
#  </span>
#  </small>
#  </div>
#  <br>
#  <a aria-label="Login to register for Saturday, June 26, 2021" class="btn btn-primary" href="#" onclick="showLogin('/Program/GetProgramDetails?courseId=0c0f9f29-eabf-4316-93a1-d0693b61e08f&amp;semesterId=3302ba85-8b33-4145-b755-2d709e0ec9ef')">Register</a>
#  </br></div>,
#  <div class="caption program-schedule-card-caption" data-instance-dates="Saturday, June 26, 2021" data-instance-id="03daba79-7fa5-4afa-a73d-efd5c69e62dd" data-instance-times="12:30 PM - 2:00 PM">
#  <label class="program-schedule-card-header">
#  					Saturday, June 26, 2021
#  			</label>
#  <div>
#  <small>
#  					12:30 PM - 2:00 PM
#  					<span class="pull-right">
#  <small>No Spots Available</small>
#  </span>
#  </small>
#  </div>
#  <br>
#  <a aria-label="Login to register for Saturday, June 26, 2021" class="btn btn-primary" href="#" onclick="showLogin('/Program/GetProgramDetails?courseId=0c0f9f29-eabf-4316-93a1-d0693b61e08f&amp;semesterId=3302ba85-8b33-4145-b755-2d709e0ec9ef')">Register</a>
#  </br></div>,
#  <div class="caption program-schedule-card-caption" data-instance-dates="Sunday, June 27, 2021" data-instance-id="547da3a9-3f3c-4440-8ffd-9c5b77dcbde8" data-instance-times="11:00 AM - 12:30 PM">
#  <label class="program-schedule-card-header">
#  					Sunday, June 27, 2021
#  			</label>
#  <div>
#  <small>
#  					11:00 AM - 12:30 PM
#  					<span class="pull-right">
#  <small>No Spots Available</small>
#  </span>
#  </small>
#  </div>
#  <br>
#  <a aria-label="Login to register for Sunday, June 27, 2021" class="btn btn-primary" href="#" onclick="showLogin('/Program/GetProgramDetails?courseId=0c0f9f29-eabf-4316-93a1-d0693b61e08f&amp;semesterId=3302ba85-8b33-4145-b755-2d709e0ec9ef')">Register</a>
#  </br></div>,
#  <div class="caption program-schedule-card-caption" data-instance-dates="Sunday, June 27, 2021" data-instance-id="5ffa57be-2e26-4b10-bd19-a4dbfc148281" data-instance-times="12:30 PM - 2:00 PM">
#  <label class="program-schedule-card-header">
#  					Sunday, June 27, 2021
#  			</label>
#  <div>
#  <small>
#  					12:30 PM - 2:00 PM
#  					<span class="pull-right">
#  <small>2 spot(s) available</small>
#  </span>
#  </small>
#  </div>
#  <br>
#  <a aria-label="Login to register for Sunday, June 27, 2021" class="btn btn-primary" href="#" onclick="showLogin('/Program/GetProgramDetails?courseId=0c0f9f29-eabf-4316-93a1-d0693b61e08f&amp;semesterId=3302ba85-8b33-4145-b755-2d709e0ec9ef')">Register</a>
#  </br></div>,
#  <div class="caption program-schedule-card-caption" data-instance-dates="Monday, June 28, 2021" data-instance-id="18ddbae4-fc7c-42ad-9e09-34473c8190e2" data-instance-times="11:00 AM - 12:30 PM">
#  <label class="program-schedule-card-header">
#  					Monday, June 28, 2021
#  			</label>
#  <div>
#  <small>
#  					11:00 AM - 12:30 PM
#  					<span class="pull-right">
#  <small>3 spot(s) available</small>
#  </span>
#  </small>
#  </div>
#  <br>
#  <a aria-label="Login to register for Monday, June 28, 2021" class="btn btn-primary" href="#" onclick="showLogin('/Program/GetProgramDetails?courseId=0c0f9f29-eabf-4316-93a1-d0693b61e08f&amp;semesterId=3302ba85-8b33-4145-b755-2d709e0ec9ef')">Register</a>
#  </br></div>,
#  <div class="caption program-schedule-card-caption" data-instance-dates="Monday, June 28, 2021" data-instance-id="62941632-f1b6-4242-bdd5-f8a046a0f5ed" data-instance-times="12:30 PM - 2:00 PM">
#  <label class="program-schedule-card-header">
#  					Monday, June 28, 2021
#  			</label>
#  <div>
#  <small>
#  					12:30 PM - 2:00 PM
#  					<span class="pull-right">
#  <small>6 spot(s) available</small>
#  </span>
#  </small>
#  </div>
#  <br>
#  <a aria-label="Login to register for Monday, June 28, 2021" class="btn btn-primary" href="#" onclick="showLogin('/Program/GetProgramDetails?courseId=0c0f9f29-eabf-4316-93a1-d0693b61e08f&amp;semesterId=3302ba85-8b33-4145-b755-2d709e0ec9ef')">Register</a>
#  </br></div>,
#  <div class="caption program-schedule-card-caption" data-instance-dates="Monday, June 28, 2021" data-instance-id="c941bb91-9561-400f-b3b5-fb7791c46472" data-instance-times="4:00 PM - 5:30 PM">
#  <label class="program-schedule-card-header">
#  					Monday, June 28, 2021
#  			</label>
#  <div>
#  <small>
#  					4:00 PM - 5:30 PM
#  					<span class="pull-right">
#  <small>2 spot(s) available</small>
#  </span>
#  </small>
#  </div>
#  <br>
#  <a aria-label="Login to register for Monday, June 28, 2021" class="btn btn-primary" href="#" onclick="showLogin('/Program/GetProgramDetails?courseId=0c0f9f29-eabf-4316-93a1-d0693b61e08f&amp;semesterId=3302ba85-8b33-4145-b755-2d709e0ec9ef')">Register</a>
#  </br></div>,
#  <div class="caption program-schedule-card-caption" data-instance-dates="Monday, June 28, 2021" data-instance-id="db2b9a20-2d2d-4cb1-b0c0-ef24ab6dd594" data-instance-times="5:30 PM - 7:00 PM">
#  <label class="program-schedule-card-header">
#  					Monday, June 28, 2021
#  			</label>
#  <div>
#  <small>
#  					5:30 PM - 7:00 PM
#  					<span class="pull-right">
#  <small>1 spot(s) available</small>
#  </span>
#  </small>
#  </div>
#  <br>
#  <a aria-label="Login to register for Monday, June 28, 2021" class="btn btn-primary" href="#" onclick="showLogin('/Program/GetProgramDetails?courseId=0c0f9f29-eabf-4316-93a1-d0693b61e08f&amp;semesterId=3302ba85-8b33-4145-b755-2d709e0ec9ef')">Register</a>
#  </br></div>]
